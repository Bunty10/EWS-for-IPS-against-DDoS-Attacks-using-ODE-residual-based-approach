# %%
"""
DLT-NN pipeline from notebook: clean, preprocess, aggregate, normalize, train, test, thresholds, confusion matrices.
Supports separate train run and test runs for Train, Test1, Test2.
"""
import pandas as pd
import numpy as np
import torch
import torch.optim as optim
import pickle
from pathlib import Path
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    balanced_accuracy_score,
)

FEATURES = ['FlowDuration','FlowBytes/s','FlowPackets/s',
            'FlowIATMean','FlowIATStd','FlowIATMax','FlowIATMin',
            'FwdIATTotal','FwdIATMean','FwdIATStd','FwdIATMax','FwdIATMin',
            'BwdIATTotal','BwdIATMean','BwdIATStd','BwdIATMax','BwdIATMin',
            'FwdPackets/s',
            'BwdPackets/s',
            'ActiveMean','ActiveStd','ActiveMax','ActiveMin',
            'IdleMean','IdleStd','IdleMax','IdleMin']

LABEL_COL = "Label"
NUM_FEATURES = len(FEATURES)


def clean_columns(df):
    """Strip and remove spaces from column names."""
    df.columns = df.columns.str.strip().str.replace(" ", "", regex=False)
    return df


def preprocess_raw(df, features):
    """Remove inf/-inf and drop rows with NaN in feature columns."""
    df = df.replace([np.inf, -np.inf], np.nan)
    df = df.dropna(subset=features).reset_index(drop=True)
    return df

def aggregate_test(df, threshold=0.07):
    """Aggregate test flows by second, compute attack ratio, adaptive label."""
    df["Timestamp"] = pd.to_datetime(df["Timestamp"], errors="coerce", format="mixed")
    df = df.dropna(subset=["Timestamp"])
    df.set_index("Timestamp", inplace=True)

    # Filter to only existing columns
    use_features = [f for f in FEATURES if f in df.columns]
    print(f"Using {len(use_features)} features: {use_features}")

    # Dynamic agg dict
    agg_dict = {f: "sum" for f in use_features}
    agg_dict['Label'] = ["size", lambda x: (x != "BENIGN").sum()]

    aggregated_df = df.resample("1s").agg(agg_dict).reset_index()

    # Flatten column names
    aggregated_df.columns = ["Timestamp"] + [
    col[0] if col[0] in use_features else f"{col[0]}_{col[1]}"
    for col in aggregated_df.columns[1:]
    ]

    # Fill NaNs
    for f in use_features:
        if f in aggregated_df.columns:
            aggregated_df[f] = aggregated_df[f].fillna(0.0)

    # Identify label columns
    label_size_col = next((c for c in aggregated_df.columns if "Label_size" in c), None)
    label_attack_col = next((c for c in aggregated_df.columns if "Label_" in c and c != label_size_col), None)

    aggregated_df["label_count"] = aggregated_df[label_size_col].fillna(0)
    aggregated_df["label_A_count"] = aggregated_df[label_attack_col].fillna(0)

    # Attack ratio
    aggregated_df["attack_ratio"] = np.where(
        aggregated_df["label_count"] > 0,
        aggregated_df["label_A_count"] / aggregated_df["label_count"],
        0
    )

    # Final label
    aggregated_df["Label"] = np.where(
        aggregated_df["attack_ratio"] >= threshold, "DDoS", "BENIGN"
    )

    # Filter empty bins
    zero_mask = pd.Series(True, index=aggregated_df.index)
    for f in use_features:
        if f in aggregated_df.columns:
            zero_mask &= (aggregated_df[f] == 0.0)
    aggregated_df = aggregated_df[~zero_mask]

    # Drop temp cols
    drop_cols = ["label_count", "label_A_count", "attack_ratio", label_size_col, label_attack_col]
    drop_cols = [c for c in drop_cols if c in aggregated_df.columns]
    aggregated_df.drop(columns=drop_cols, inplace=True)

    # Sequential timestamp
    aggregated_df["Timestamp_sec"] = range(1, len(aggregated_df) + 1)
    aggregated_df = aggregated_df[["Timestamp_sec"] + [c for c in aggregated_df.columns if c != "Timestamp_sec"]]

    return aggregated_df

def transpose(df):
    """Normalize features: (x - mean) / std. Matches notebook exactly."""
    df = df.T
    return df

def finite_differents(Z,N):
    if Z.shape[0] == 27:
        Zi_dot = np.zeros((27, N-1))
        for i in range(N-1):
            Zi_dot[:, i] = Z[:, i+1] - Z[:, i]  # Column-wise difference
        return Zi_dot
    elif  Z.shape[1] == 27:
        Z_dot = np.zeros((N-1, 27))
        for i in range(N-1):
            Z_dot[i] = Z[i+1] - Z[i]  # Column-wise difference
        return Z_dot

def trimmed(Z):
    Z_trimmed = Z[:-1, :]
    return Z_trimmed

def System_matrix(Z_t, Z_trimmed, Z_dot):
    gram_matrix = Z_t @ Z_trimmed
    Z_inv = np.linalg.inv(gram_matrix)
    matrix = Z_inv @ Z_t @ Z_dot
    Az = matrix.T
    return Az

def Z_PINN(Az, Z_t, Zi_dot):
    Z_PINN = Az @ Z_t
    PINN_Residual = Zi_dot - Z_PINN
    R_PINN = np.sum(PINN_Residual, axis=0)
    return R_PINN

def Z_LAPLACE(Az, Z_t):
    S = 1
    n_rows, n_cols = Az.shape
    I = np.eye(n_rows)
    Z_Laplace_matrix = (S * I) - Az
    Z_Laplace = Z_Laplace_matrix @ Z_t
    Laplace_Residual = Z_t - Z_Laplace
    R_Laplace = np.sum(Laplace_Residual, axis=0)
    return R_Laplace

def run_train_only(train_df, results_folder, model_folder):
    """Run train pipeline only. Saves model and thresholds. Returns train results (no confusion matrix)."""
    results_folder = Path(results_folder)
    results_folder.mkdir(parents=True, exist_ok=True)
    
    model_folder = Path(model_folder)
    model_folder.mkdir(parents=True, exist_ok=True)
    
    train_df = clean_columns(train_df)
    if not all(f in train_df.columns for f in FEATURES):
        raise ValueError(f"Train CSV must contain columns: {FEATURES}")
    
    train_df = preprocess_raw(train_df, FEATURES)
    df_train = aggregate_test(train_df)
    # BENIGN only
    df_train = df_train[df_train[LABEL_COL] == "BENIGN"]
    N = len(df_train)
    df_train_27 = df_train[['FlowDuration','FlowBytes/s','FlowPackets/s', 'FlowIATMean', 'FlowIATStd',
                        'FlowIATMax', 'FlowIATMin', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd',
                        'FwdIATMax', 'FwdIATMin', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd',
                        'BwdIATMax', 'BwdIATMin', 'FwdPackets/s', 'BwdPackets/s', 'ActiveMean',
                        'ActiveStd', 'ActiveMax', 'ActiveMin', 'IdleMean', 'IdleStd', 'IdleMax',
                        'IdleMin']].values  # Shape: (n_rows, 4)
    df_train_t = transpose(df_train_27)
    df_train_t_dot = finite_differents(df_train_t,N)
    df_train_dot = finite_differents(df_train_27,N)
    df_train_trim = trimmed(df_train_27)
    df_train_trim_t = transpose(df_train_trim)
    df_train_Az = System_matrix(df_train_trim_t,df_train_trim,df_train_dot)
    df_train_R_PINN = Z_PINN(df_train_Az, df_train_trim_t, df_train_t_dot)
    df_train_R_Laplace = Z_LAPLACE(df_train_Az, df_train_trim_t)
    df_train_R = df_train_R_PINN + df_train_R_Laplace
    df_train.loc[df_train.index[:-1], "score"] = df_train_R

    # Thresholds based on mean + k*std
    mu = df_train_R.mean()
    std = df_train_R.std()
    LOW_THR = mu + 1 * std
    MED_THR = mu + 2 * std
    HIGH_THR = mu + 3 * std
    ews_thresholds = {"LOW": float(LOW_THR), "MED": float(MED_THR), "HIGH": float(HIGH_THR)}
    # Residual stats (global, not per-feature)
    residual_stats = {"mean": float(mu),
                      "std": float(std),
                      "max": float(df_train_R.max())
                     }
    # Save for test runs
    with open(model_folder / "thresholds_M2_VNRVJIET.pkl", "wb") as f:
        pickle.dump({
            "thresholds": ews_thresholds,
            "LOW_THR": LOW_THR,
            "MED_THR": MED_THR,
            "HIGH_THR": HIGH_THR,
        }, f)
    max_seconds = int(df_train["Timestamp_sec"].max())
    traffic_data = []
    
    for _, row in df_train.iterrows():
        row_dict = {
            "second": int(row["Timestamp_sec"]),
            "Label": str(row["Label"])
        }
        # Add all features dynamically
        for f in FEATURES:
            safe_key = f.replace(" ", "_").replace("/", "_")  # normalize key names
            row_dict[safe_key] = float(row[f]) if f in row else 0.0
        traffic_data.append(row_dict)
    
    return {
        "traffic_data": traffic_data,
        "max_seconds": max_seconds,
        "thresholds": ews_thresholds,
        "residual_stats": residual_stats,
    }  

def run_test_only(test_df, results_folder, model_folder):
    """Load model and thresholds, run test pipeline. Returns test results with confusion matrices and Kurtosis."""
    results_folder = Path(results_folder)
    model_folder = Path(model_folder)
    with open(model_folder / "thresholds_M2_VNRVJIET.pkl", "rb") as f:
        th = pickle.load(f)
    LOW_THR = th["LOW_THR"]
    MED_THR = th["MED_THR"]
    HIGH_THR = th["HIGH_THR"]

    if test_df.empty:
        raise ValueError("Test CSV file is empty.")
    test_df = clean_columns(test_df)
    required = FEATURES + [LABEL_COL, "Timestamp"]
    missing = [c for c in required if c not in test_df.columns]
    if missing:
        raise ValueError(
            f"Test CSV must contain columns: Timestamp, FlowPackets/s, FlowBytes/s, Label. Missing: {missing}. "
            "Column names are normalized (spaces stripped)."
        )
    
    test_df = preprocess_raw(test_df, FEATURES)
    if test_df.empty:
        raise ValueError("No valid rows after preprocessing (check for NaN/inf in FlowPackets/s and FlowBytes/s).")
    df_test = aggregate_test(test_df)
    N = len(df_test)
    df_test_27 = df_test[['FlowDuration','FlowBytes/s','FlowPackets/s', 'FlowIATMean', 'FlowIATStd',
                        'FlowIATMax', 'FlowIATMin', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd',
                        'FwdIATMax', 'FwdIATMin', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd',
                        'BwdIATMax', 'BwdIATMin', 'FwdPackets/s', 'BwdPackets/s', 'ActiveMean',
                        'ActiveStd', 'ActiveMax', 'ActiveMin', 'IdleMean', 'IdleStd', 'IdleMax',
                        'IdleMin']].values  # Shape: (n_rows, 4)
    df_test_t = transpose(df_test_27)
    df_test_t_dot = finite_differents(df_test_t,N)
    df_test_dot = finite_differents(df_test_27,N)
    df_test_trim = trimmed(df_test_27)
    df_test_trim_t = transpose(df_test_trim)
    df_test_Az = System_matrix(df_test_trim_t,df_test_trim,df_test_dot)
    df_test_R_PINN = Z_PINN(df_test_Az, df_test_trim_t, df_test_t_dot)
    df_test_R_Laplace = Z_LAPLACE(df_test_Az, df_test_trim_t)
    df_test_R = df_test_R_PINN + df_test_R_Laplace
    # trimmed_df_test = df_test[:-1]

    # Store scores in DataFrame for inspection
    # trimmed_df_test["score"] = df_test_R
    df_test.loc[df_test.index[:-1], "score"] = df_test_R

    def assign_warning(R):
        if R <= LOW_THR:
            return "BENIGN"
        if R <= MED_THR:
            return "LOW"
        if R <= HIGH_THR:
            return "MED"
        return "HIGH"

    df_test["Warning"] = df_test["score"].apply(assign_warning)

    # Confusion matrices and metrics (notebook: filter by flow_peak_time and BENIGN|Warning==level)
    flow_peak_time = df_test.loc[df_test["FlowPackets/s"].idxmax(), "Timestamp_sec"]
    df_r = df_test[df_test["Timestamp_sec"] <= flow_peak_time].copy()
    confusion_matrices = {}
    confusion_metrics = {}
    for level in ["LOW", "MED", "HIGH"]:
        df_sub = df_r[(df_r["Label"] == "BENIGN") | (df_r["Warning"] == level)]
        if df_sub.empty:
            # Gracefully handle cases where there are no samples for this level
            # (e.g., all traffic is BENIGN and model never produces this warning).
            cm = np.array([[0, 0], [0, 0]], dtype=int)
            confusion_matrices[level] = cm.tolist()
            confusion_metrics[level] = {
                "accuracy": 0.0,
                "precision_attack": 0.0,
                "recall_attack": 0.0,
                "f1_attack": 0.0,
                "balanced_accuracy": 0.0,
            }
            continue

        y_true = df_sub["Label"].apply(lambda x: 0 if x == "BENIGN" else 1).values
        y_pred = df_sub["Warning"].apply(lambda x: 1 if x == level else 0).values
        cm = confusion_matrix(y_true, y_pred, labels=[0, 1])
        confusion_matrices[level] = cm.tolist()
        confusion_metrics[level] = {
            "accuracy": float(accuracy_score(y_true, y_pred)),
            "precision_attack": float(precision_score(y_true, y_pred, pos_label=1, zero_division=0)),
            "recall_attack": float(recall_score(y_true, y_pred, pos_label=1, zero_division=0)),
            "f1_attack": float(f1_score(y_true, y_pred, pos_label=1, zero_division=0)),
            "balanced_accuracy": float(balanced_accuracy_score(y_true, y_pred)),
        }

    y_true = (df_test["Label"] != "BENIGN").astype(int).values
    y_pred_high = (df_test["Warning"] == "HIGH").astype(int).values
    tp = ((y_true == 1) & (y_pred_high == 1)).sum()
    fn = ((y_true == 1) & (y_pred_high == 0)).sum()
    fp = ((y_true == 0) & (y_pred_high == 1)).sum()
    tn = ((y_true == 0) & (y_pred_high == 0)).sum()
    detection_rate = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    false_positive_rate = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    warnings_count = {k: int(v) for k, v in df_test["Warning"].value_counts().to_dict().items()}

    # First warning times and peak (for frontend graphs)
    first_low = float(df_test.loc[df_test["Warning"] == "LOW", "Timestamp_sec"].min()) if (df_test["Warning"] == "LOW").any() else None
    first_med = float(df_test.loc[df_test["Warning"] == "MED", "Timestamp_sec"].min()) if (df_test["Warning"] == "MED").any() else None
    first_high = float(df_test.loc[df_test["Warning"] == "HIGH", "Timestamp_sec"].min()) if (df_test["Warning"] == "HIGH").any() else None
    peak_idx = df_test["FlowPackets/s"].idxmax()
    peak_sec = int(df_test.loc[peak_idx, "Timestamp_sec"])
    peak_val = float(df_test.loc[peak_idx, "FlowPackets/s"])

    max_seconds = int(df_test["Timestamp_sec"].max())
    traffic_data = []
    for _, row in df_test.iterrows():
        traffic_data.append({
            "second": int(row["Timestamp_sec"]),
            "FlowPackets_s": float(row["FlowPackets/s"]),
            "FlowBytes_s": float(row["FlowBytes/s"]),
            "Label": str(row["Label"]),
            "Warning": str(row["Warning"]),
            "score": float(row["score"])
        })

    return {
        "detection_rate": detection_rate,
        "false_positive_rate": false_positive_rate,
        "warnings": warnings_count,
        "traffic_data": traffic_data,
        "max_seconds": max_seconds,
        "confusion_matrices": confusion_matrices,
        "confusion_metrics": confusion_metrics,
        "first_low": first_low,
        "first_med": first_med,
        "first_high": first_high,
        "peak_sec": peak_sec,
        "peak_val": peak_val,
    }

def run_full_pipeline(train_path, test1_path, test2_path, results_folder, model_folder):
    """Run train once, then test for test1 and test2. Returns { train, test1, test2 }."""
    train_results = run_train_only(train_path, results_folder, model_folder)
    test1_results = run_test_only(test1_path, results_folder, model_folder)
    test2_results = run_test_only(test2_path, results_folder, model_folder)
    return {
        "train": train_results,
        "test1": test1_results,
        "test2": test2_results,
    }

# %%
from pathlib import Path
import os

MODEL_FOLDER = r"D:\Datasets\GUI\GUI_EWS_Approach\backend\models"
RESULTS_FOLDER = r"D:\Datasets\GUI\GUI_EWS_Approach\backend\results"
UPLOAD_FOLDER = r"D:\Datasets\GUI\GUI_EWS_Approach\backend\uploads"


# train_path = pd.read_csv(r"D:\Datasets\GUI\GUI_EWS_Approach\backend\uploads\train.csv") 
# train_path = pd.read_csv(r"D:\Datasets\GUI\GUI_EWS_Approach\backend\results\live_capture_VNRVJIET.csv") 

# test1_path = pd.read_csv(r"D:\Datasets\GUI\GUI_EWS_Approach\backend\uploads\test_1.csv") 
test1_path = pd.read_csv(r"D:\Datasets\GUI\GUI_EWS_Approach\backend\results\live_capture_VNRVJIET.csv")

# test2_path = pd.read_csv(r"D:\Datasets\GUI\GUI_EWS_Approach\backend\uploads\test_2.csv") 

# results = run_full_pipeline(train_path, test1_path, test2_path, RESULTS_FOLDER, MODEL_FOLDER)

# results = run_train_only(train_path, RESULTS_FOLDER, MODEL_FOLDER)
results1 = run_test_only(test1_path, RESULTS_FOLDER, MODEL_FOLDER)

# results_1 = run_test_only(test2_path, RESULTS_FOLDER, MODEL_FOLDER)
# Out:
# Using 27 features: ['FlowDuration', 'FlowBytes/s', 'FlowPackets/s', 'FlowIATMean', 'FlowIATStd', 'FlowIATMax', 'FlowIATMin', 'FwdIATTotal', 'FwdIATMean', 'FwdIATStd', 'FwdIATMax', 'FwdIATMin', 'BwdIATTotal', 'BwdIATMean', 'BwdIATStd', 'BwdIATMax', 'BwdIATMin', 'FwdPackets/s', 'BwdPackets/s', 'ActiveMean', 'ActiveStd', 'ActiveMax', 'ActiveMin', 'IdleMean', 'IdleStd', 'IdleMax', 'IdleMin']
# C:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:2524: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# C:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:2524: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")
# C:\Users\asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:2524: UserWarning: y_pred contains classes not in y_true
#   warnings.warn("y_pred contains classes not in y_true")

# %%
# results

# %%
results1
# Out:
# {'detection_rate': 0.0,
#  'false_positive_rate': np.float64(0.0028228652081863093),
#  'warnings': {'BENIGN': 1411, 'HIGH': 4, 'LOW': 1, 'MED': 1},
#  'traffic_data': [{'second': 1,
#    'FlowPackets_s': 0.9981181983958867,
#    'FlowBytes_s': 150.63739973588457,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 2,
#    'FlowPackets_s': 0.1187291409522653,
#    'FlowBytes_s': 7.598665020944981,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 3,
#    'FlowPackets_s': 0.23546502867283609,
#    'FlowBytes_s': 35.66787679785718,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 4,
#    'FlowPackets_s': 0.08199356280822451,
#    'FlowBytes_s': 4.849850079075667,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 5,
#    'FlowPackets_s': 0.0717035836036192,
#    'FlowBytes_s': 5.890449393037321,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 6,
#    'FlowPackets_s': 3.8266026629294667,
#    'FlowBytes_s': 972.5837828915733,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 7,
#    'FlowPackets_s': 22.040794075795045,
#    'FlowBytes_s': 5203.923058592821,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 8,
#    'FlowPackets_s': 2681.6541432495683,
#    'FlowBytes_s': 148445.49906375483,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -98304.0},
#   {'second': 9,
#    'FlowPackets_s': 0.0465030214585856,
#    'FlowBytes_s': 2.8332211452970695,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 10,
#    'FlowPackets_s': 0.001452696616634,
#    'FlowBytes_s': 0.3530052778420752,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 11,
#    'FlowPackets_s': 0.21320999937899948,
#    'FlowBytes_s': 18.65547142878526,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 12,
#    'FlowPackets_s': 0.0585561000633069,
#    'FlowBytes_s': 3.689034303988336,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 13,
#    'FlowPackets_s': 0.623035358210513,
#    'FlowBytes_s': 131.8784795317318,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 14,
#    'FlowPackets_s': 0.0258663410642982,
#    'FlowBytes_s': 2.401052391473289,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 15,
#    'FlowPackets_s': 0.0121880936755918,
#    'FlowBytes_s': 0.7398670334295478,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 16,
#    'FlowPackets_s': 0.046037489903601195,
#    'FlowBytes_s': 2.804388597231511,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 17,
#    'FlowPackets_s': 0.0717524362486143,
#    'FlowBytes_s': 4.612785023077429,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 18,
#    'FlowPackets_s': 0.13184643154215459,
#    'FlowBytes_s': 9.388918716096066,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 19,
#    'FlowPackets_s': 1077.5344047573876,
#    'FlowBytes_s': 535965.4830797364,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 20,
#    'FlowPackets_s': 0.0711855624509174,
#    'FlowBytes_s': 3.8677488931665134,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 21,
#    'FlowPackets_s': 33.98809605943463,
#    'FlowBytes_s': 16531.85200010202,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 22,
#    'FlowPackets_s': 0.5873234193003167,
#    'FlowBytes_s': 71.2720460784834,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 23,
#    'FlowPackets_s': 0.057441671877961,
#    'FlowBytes_s': 3.6188253283115457,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 24,
#    'FlowPackets_s': 2.7609434756399853,
#    'FlowBytes_s': 2706.540337991409,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 25,
#    'FlowPackets_s': 0.1797817633979853,
#    'FlowBytes_s': 46.02786035067528,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 26,
#    'FlowPackets_s': 0.0131257068974413,
#    'FlowBytes_s': 1.0814484720002584,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 27,
#    'FlowPackets_s': 0.0333543022904746,
#    'FlowBytes_s': 1.8278157655180105,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 28,
#    'FlowPackets_s': 0.0400373668370194,
#    'FlowBytes_s': 2.188709387090398,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 29,
#    'FlowPackets_s': 135.9319381984456,
#    'FlowBytes_s': 66225.65878284443,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 30,
#    'FlowPackets_s': 195.03599506707724,
#    'FlowBytes_s': 75344.84799370833,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -65536.0},
#   {'second': 31,
#    'FlowPackets_s': 8.81083917378345,
#    'FlowBytes_s': 9883.294744759187,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 32,
#    'FlowPackets_s': 1.0795786039385349,
#    'FlowBytes_s': 379.6529920023594,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 33,
#    'FlowPackets_s': 0.007990086063459599,
#    'FlowBytes_s': 1.0926442683555564,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 34,
#    'FlowPackets_s': 0.2735128478704391,
#    'FlowBytes_s': 156.43215556566759,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 35,
#    'FlowPackets_s': 24.34320099976745,
#    'FlowBytes_s': 1487.8230008441158,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 36,
#    'FlowPackets_s': 0.0798481735155601,
#    'FlowBytes_s': 78.6185116434205,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 37,
#    'FlowPackets_s': 26.23278556436537,
#    'FlowBytes_s': 2113.096106150259,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 376832.0},
#   {'second': 38,
#    'FlowPackets_s': 181.24192430647653,
#    'FlowBytes_s': 377298.2586128077,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -376832.0},
#   {'second': 39,
#    'FlowPackets_s': 3.66850642724224,
#    'FlowBytes_s': 311.8230463155904,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 5963776.0},
#   {'second': 40,
#    'FlowPackets_s': 1493.0752934111222,
#    'FlowBytes_s': 5969599.3733209735,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -6291456.0},
#   {'second': 41,
#    'FlowPackets_s': 564.5588033487006,
#    'FlowBytes_s': 235436.28778520424,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 285696.0},
#   {'second': 42,
#    'FlowPackets_s': 1026.151444334369,
#    'FlowBytes_s': 516005.7033934462,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 43,
#    'FlowPackets_s': 0.8878057004604984,
#    'FlowBytes_s': 227.83744344965965,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 44,
#    'FlowPackets_s': 0.34760339823334585,
#    'FlowBytes_s': 137.4607741867983,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 45,
#    'FlowPackets_s': 1.0873939458399304,
#    'FlowBytes_s': 906.1703105472629,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 46,
#    'FlowPackets_s': 0.1545159461591265,
#    'FlowBytes_s': 31.34439884994338,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 47,
#    'FlowPackets_s': 1.6866234470987065,
#    'FlowBytes_s': 1983.4372213565248,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 48,
#    'FlowPackets_s': 0.7886894250742881,
#    'FlowBytes_s': 205.80876718955224,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 49,
#    'FlowPackets_s': 0.5271156158307717,
#    'FlowBytes_s': 395.8388802384214,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 50,
#    'FlowPackets_s': 2.798871912871424,
#    'FlowBytes_s': 1020.8437625270244,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 51,
#    'FlowPackets_s': 3.572830843834842,
#    'FlowBytes_s': 4615.636427296549,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 52,
#    'FlowPackets_s': 0.5116246988172319,
#    'FlowBytes_s': 177.519442253842,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 53,
#    'FlowPackets_s': 0.3015578345936362,
#    'FlowBytes_s': 197.39599429313364,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 54,
#    'FlowPackets_s': 606.6470467206045,
#    'FlowBytes_s': 303215.122945193,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -360448.0},
#   {'second': 55,
#    'FlowPackets_s': 0.18179505573818172,
#    'FlowBytes_s': 50.52120296343768,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 56,
#    'FlowPackets_s': 0.3089387688960106,
#    'FlowBytes_s': 122.26350921697664,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 57,
#    'FlowPackets_s': 1.4959832693140036,
#    'FlowBytes_s': 1932.8103839536927,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 58,
#    'FlowPackets_s': 0.184670686217228,
#    'FlowBytes_s': 85.78496523867351,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 59,
#    'FlowPackets_s': 0.419846584144605,
#    'FlowBytes_s': 291.3655862509174,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 60,
#    'FlowPackets_s': 0.8860451241843733,
#    'FlowBytes_s': 228.44030392466163,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 61,
#    'FlowPackets_s': 6.2603364396477215,
#    'FlowBytes_s': 1918.6912553529667,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 62,
#    'FlowPackets_s': 14.04532073787631,
#    'FlowBytes_s': 7819.694871642952,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 63,
#    'FlowPackets_s': 0.3675543354981377,
#    'FlowBytes_s': 174.0392405134735,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 64,
#    'FlowPackets_s': 0.9549651256233662,
#    'FlowBytes_s': 241.01390897693886,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 65,
#    'FlowPackets_s': 827.4939166785499,
#    'FlowBytes_s': 435698.42008659185,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -393216.0},
#   {'second': 66,
#    'FlowPackets_s': 0.2534912200716311,
#    'FlowBytes_s': 98.25338743202107,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 67,
#    'FlowPackets_s': 0.8219445278990565,
#    'FlowBytes_s': 207.35918485333912,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 68,
#    'FlowPackets_s': 0.43447569778848627,
#    'FlowBytes_s': 74.39919277893368,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 69,
#    'FlowPackets_s': 0.9874893937949173,
#    'FlowBytes_s': 899.566178237143,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 70,
#    'FlowPackets_s': 7.292184332502286,
#    'FlowBytes_s': 1888.675742118092,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 8192.0},
#   {'second': 71,
#    'FlowPackets_s': 7.324319300567144,
#    'FlowBytes_s': 6214.278019903412,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -8192.0},
#   {'second': 72,
#    'FlowPackets_s': 1.099686339861899,
#    'FlowBytes_s': 266.3177845932085,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 73,
#    'FlowPackets_s': 0.6120572979869804,
#    'FlowBytes_s': 250.6272476155845,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 74,
#    'FlowPackets_s': 1132.3473292161955,
#    'FlowBytes_s': 563321.3974275229,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -557056.0},
#   {'second': 75,
#    'FlowPackets_s': 0.1789193033928295,
#    'FlowBytes_s': 37.514797466472444,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 76,
#    'FlowPackets_s': 0.7894966971664907,
#    'FlowBytes_s': 152.7437657184032,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 77,
#    'FlowPackets_s': 0.0975572126090115,
#    'FlowBytes_s': 25.39499482098237,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 78,
#    'FlowPackets_s': 1.0709551892973983,
#    'FlowBytes_s': 1007.600254646514,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 79,
#    'FlowPackets_s': 5.864411865599958,
#    'FlowBytes_s': 1322.8170349644552,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 80,
#    'FlowPackets_s': 0.1788440588378232,
#    'FlowBytes_s': 43.74591535252986,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 81,
#    'FlowPackets_s': 0.1258564113438339,
#    'FlowBytes_s': 18.9238525384532,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 82,
#    'FlowPackets_s': 0.1341100899378531,
#    'FlowBytes_s': 33.03853646422835,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 83,
#    'FlowPackets_s': 0.6029329049912633,
#    'FlowBytes_s': 301.331710185148,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 84,
#    'FlowPackets_s': 0.2566420620092451,
#    'FlowBytes_s': 124.88113080998421,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 85,
#    'FlowPackets_s': 0.3004073310956624,
#    'FlowBytes_s': 178.8288791514814,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 86,
#    'FlowPackets_s': 0.1286691483316932,
#    'FlowBytes_s': 27.34934230650324,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 87,
#    'FlowPackets_s': 2.400334020500432,
#    'FlowBytes_s': 2709.4217440566426,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 88,
#    'FlowPackets_s': 10.380100470386138,
#    'FlowBytes_s': 1329.0963731044558,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 89,
#    'FlowPackets_s': 0.0826229792221892,
#    'FlowBytes_s': 8.278822518063366,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 90,
#    'FlowPackets_s': 0.1485303626414055,
#    'FlowBytes_s': 52.80006841297564,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 91,
#    'FlowPackets_s': 0.1588107142397218,
#    'FlowBytes_s': 20.25290351454281,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 92,
#    'FlowPackets_s': 0.7515968160753517,
#    'FlowBytes_s': 173.9215001333755,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 93,
#    'FlowPackets_s': 1112.9763043716027,
#    'FlowBytes_s': 553648.3391249392,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -557056.0},
#   {'second': 94,
#    'FlowPackets_s': 0.432617154808811,
#    'FlowBytes_s': 176.1990994460292,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 95,
#    'FlowPackets_s': 0.1998509722332894,
#    'FlowBytes_s': 112.98162408668519,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 96,
#    'FlowPackets_s': 0.8876848027612356,
#    'FlowBytes_s': 226.7538734659277,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 97,
#    'FlowPackets_s': 0.4236350684192206,
#    'FlowBytes_s': 176.74650578676471,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 98,
#    'FlowPackets_s': 0.1765664943849589,
#    'FlowBytes_s': 89.58341865113232,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 99,
#    'FlowPackets_s': 1.2750180834384102,
#    'FlowBytes_s': 1047.6101830474167,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 100,
#    'FlowPackets_s': 0.0002202103049989,
#    'FlowBytes_s': 0.0188279810774081,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 101,
#    'FlowPackets_s': 0.1638542932128485,
#    'FlowBytes_s': 117.62586621516814,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 102,
#    'FlowPackets_s': 2.148774949983756,
#    'FlowBytes_s': 3034.032335557447,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 103,
#    'FlowPackets_s': 1.6190397963483076,
#    'FlowBytes_s': 3434.738965149527,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 104,
#    'FlowPackets_s': 5.324986970077122,
#    'FlowBytes_s': 7587.013634895385,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 105,
#    'FlowPackets_s': 1.150657615698034,
#    'FlowBytes_s': 818.1902424252138,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 106,
#    'FlowPackets_s': 28.276143954510705,
#    'FlowBytes_s': 7008.8089253717135,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 2490368.0},
#   {'second': 107,
#    'FlowPackets_s': 4055.38828546493,
#    'FlowBytes_s': 2562413.4896220886,
#    'Label': 'BENIGN',
#    'Warning': 'LOW',
#    'score': 35225600.0},
#   {'second': 108,
#    'FlowPackets_s': 148470.35227649333,
#    'FlowBytes_s': 37481184.87922355,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -37945344.0},
#   {'second': 109,
#    'FlowPackets_s': 0.2131409380518241,
#    'FlowBytes_s': 41.015136161933086,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 110,
#    'FlowPackets_s': 0.8875850875753757,
#    'FlowBytes_s': 228.82675462039526,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 111,
#    'FlowPackets_s': 48.130663550786956,
#    'FlowBytes_s': 31604.091490491974,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 112,
#    'FlowPackets_s': 0.2410677268696317,
#    'FlowBytes_s': 104.47085524105711,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 113,
#    'FlowPackets_s': 0.0914572628647233,
#    'FlowBytes_s': 19.513341469652566,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 114,
#    'FlowPackets_s': 0.9212910685765683,
#    'FlowBytes_s': 230.4942015905783,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 115,
#    'FlowPackets_s': 0.7455014169871641,
#    'FlowBytes_s': 225.45602291690977,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 116,
#    'FlowPackets_s': 977.0439572755934,
#    'FlowBytes_s': 496012.25096042064,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -491520.0},
#   {'second': 117,
#    'FlowPackets_s': 0.5267963322225301,
#    'FlowBytes_s': 77.41474446386117,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 118,
#    'FlowPackets_s': 0.1665297190438114,
#    'FlowBytes_s': 52.35570496547279,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 119,
#    'FlowPackets_s': 26.88081576958561,
#    'FlowBytes_s': 14953.475013743999,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 120,
#    'FlowPackets_s': 44.080382546218104,
#    'FlowBytes_s': 19249.357788631976,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 196608.0},
#   {'second': 121,
#    'FlowPackets_s': 9.619425096169966,
#    'FlowBytes_s': 817.7746697549849,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 122,
#    'FlowPackets_s': 0.1674002468715255,
#    'FlowBytes_s': 60.50123922348385,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 123,
#    'FlowPackets_s': 0.1120859414522143,
#    'FlowBytes_s': 140.13544830063094,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 124,
#    'FlowPackets_s': 188.05758318514884,
#    'FlowBytes_s': 76205.03696106312,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 125,
#    'FlowPackets_s': 146.00071226236025,
#    'FlowBytes_s': 106907.31484089211,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 126,
#    'FlowPackets_s': 23.56153370607271,
#    'FlowBytes_s': 17601.703800855474,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -16384.0},
#   {'second': 127,
#    'FlowPackets_s': 22.831789828148423,
#    'FlowBytes_s': 12274.596448377926,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -16384.0},
#   {'second': 128,
#    'FlowPackets_s': 0.16362606568542282,
#    'FlowBytes_s': 42.723796057885885,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 129,
#    'FlowPackets_s': 152.97817571662105,
#    'FlowBytes_s': 69005.79467732176,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 130,
#    'FlowPackets_s': 77.93933090922721,
#    'FlowBytes_s': 75968.03124387444,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -65536.0},
#   {'second': 131,
#    'FlowPackets_s': 1.154250093460917,
#    'FlowBytes_s': 288.5432648437109,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 132,
#    'FlowPackets_s': 0.2383852345342667,
#    'FlowBytes_s': 143.75879564626308,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 133,
#    'FlowPackets_s': 0.40996556719444466,
#    'FlowBytes_s': 179.1823990248608,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 134,
#    'FlowPackets_s': 10.434090815084165,
#    'FlowBytes_s': 6639.9613714589605,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 135,
#    'FlowPackets_s': 0.4654024836641544,
#    'FlowBytes_s': 195.00956833310576,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 136,
#    'FlowPackets_s': 1.0422757935479932,
#    'FlowBytes_s': 1004.8973507896366,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 1048576.0},
#   {'second': 137,
#    'FlowPackets_s': 1425.5209731018872,
#    'FlowBytes_s': 715014.0805669738,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -688128.0},
#   {'second': 138,
#    'FlowPackets_s': 0.3583447309677803,
#    'FlowBytes_s': 119.66147648558345,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 139,
#    'FlowPackets_s': 1.2654915702979888,
#    'FlowBytes_s': 334.10924970064775,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 140,
#    'FlowPackets_s': 0.3996865785474609,
#    'FlowBytes_s': 153.14197152725728,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 141,
#    'FlowPackets_s': 0.1595027976130901,
#    'FlowBytes_s': 114.51161562922636,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 142,
#    'FlowPackets_s': 1.6805679934878688,
#    'FlowBytes_s': 1988.882896244466,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 143,
#    'FlowPackets_s': 0.36371302539769146,
#    'FlowBytes_s': 140.75734601902184,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 144,
#    'FlowPackets_s': 0.766665043940826,
#    'FlowBytes_s': 1052.9670762765354,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 145,
#    'FlowPackets_s': 0.3250990251176474,
#    'FlowBytes_s': 154.85397660083868,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 6291456.0},
#   {'second': 146,
#    'FlowPackets_s': 1199.8758398699847,
#    'FlowBytes_s': 5852821.07862683,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 950272.0},
#   {'second': 147,
#    'FlowPackets_s': 2162.5385164230493,
#    'FlowBytes_s': 6808266.60672249,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -8388608.0},
#   {'second': 148,
#    'FlowPackets_s': 1098.394046961663,
#    'FlowBytes_s': 548613.2808451799,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -557056.0},
#   {'second': 149,
#    'FlowPackets_s': 0.1036120324408598,
#    'FlowBytes_s': 25.902538607444672,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 150,
#    'FlowPackets_s': 0.5006198759552122,
#    'FlowBytes_s': 209.35286548619635,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 151,
#    'FlowPackets_s': 0.2550622773308544,
#    'FlowBytes_s': 49.06438803563137,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 152,
#    'FlowPackets_s': 0.2559629020199377,
#    'FlowBytes_s': 194.7852014912867,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 153,
#    'FlowPackets_s': 46.26395729632554,
#    'FlowBytes_s': 9945.983849378043,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -8192.0},
#   {'second': 154,
#    'FlowPackets_s': 0.6849669095559809,
#    'FlowBytes_s': 214.80394092986757,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 155,
#    'FlowPackets_s': 0.1815207017619307,
#    'FlowBytes_s': 111.96877148029837,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 156,
#    'FlowPackets_s': 0.6810873201951646,
#    'FlowBytes_s': 237.3800723071841,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 157,
#    'FlowPackets_s': 2.8161819037468137,
#    'FlowBytes_s': 1606.463234414366,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 158,
#    'FlowPackets_s': 1011.0127436610695,
#    'FlowBytes_s': 502824.4435891294,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 159,
#    'FlowPackets_s': 0.4521278427857671,
#    'FlowBytes_s': 45.00156067731319,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 160,
#    'FlowPackets_s': 0.19143581291388911,
#    'FlowBytes_s': 39.520032008233606,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 161,
#    'FlowPackets_s': 0.5881054329892289,
#    'FlowBytes_s': 275.67250337478345,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 162,
#    'FlowPackets_s': 0.24938124622046481,
#    'FlowBytes_s': 92.97954586212302,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 163,
#    'FlowPackets_s': 7.0165927021008905,
#    'FlowBytes_s': 3427.081573317877,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 164,
#    'FlowPackets_s': 0.963126488398647,
#    'FlowBytes_s': 1023.6877518248856,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 165,
#    'FlowPackets_s': 13.717620541991044,
#    'FlowBytes_s': 8671.623178048325,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 166,
#    'FlowPackets_s': 0.1789202157392346,
#    'FlowBytes_s': 37.73554052083443,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 167,
#    'FlowPackets_s': 1027.7477517457983,
#    'FlowBytes_s': 519719.6559066157,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -2097152.0},
#   {'second': 168,
#    'FlowPackets_s': 0.186094422667275,
#    'FlowBytes_s': 87.14692346201039,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 169,
#    'FlowPackets_s': 0.447176309539714,
#    'FlowBytes_s': 296.5492725590258,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 170,
#    'FlowPackets_s': 0.8848073639792852,
#    'FlowBytes_s': 221.89002507850716,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 171,
#    'FlowPackets_s': 0.1903847910301488,
#    'FlowBytes_s': 49.85611409869526,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 172,
#    'FlowPackets_s': 0.2746415569241792,
#    'FlowBytes_s': 89.38668762706624,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 173,
#    'FlowPackets_s': 11.725318780527024,
#    'FlowBytes_s': 4205.5249651631575,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 174,
#    'FlowPackets_s': 0.7290444539497051,
#    'FlowBytes_s': 172.03651388490536,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 175,
#    'FlowPackets_s': 871.806318034449,
#    'FlowBytes_s': 428793.4048415878,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -458752.0},
#   {'second': 176,
#    'FlowPackets_s': 0.1019109832476765,
#    'FlowBytes_s': 30.012908466008575,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 177,
#    'FlowPackets_s': 1.360343148276955,
#    'FlowBytes_s': 1027.80872976633,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 178,
#    'FlowPackets_s': 0.7562692413329202,
#    'FlowBytes_s': 158.3239043909466,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 179,
#    'FlowPackets_s': 0.0873913292368012,
#    'FlowBytes_s': 21.015533935516498,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 180,
#    'FlowPackets_s': 0.7108002701451913,
#    'FlowBytes_s': 322.72610020118196,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 181,
#    'FlowPackets_s': 284.8792980905359,
#    'FlowBytes_s': 104019.8367597898,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 182,
#    'FlowPackets_s': 0.9213769565850458,
#    'FlowBytes_s': 228.73026771813616,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 262144.0},
#   {'second': 183,
#    'FlowPackets_s': 706.1747714476452,
#    'FlowBytes_s': 351444.78112834715,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 184,
#    'FlowPackets_s': 0.6587101248430639,
#    'FlowBytes_s': 163.4584360747721,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 185,
#    'FlowPackets_s': 0.0127493964075555,
#    'FlowBytes_s': 1.9394682823957705,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 186,
#    'FlowPackets_s': 0.356097026143808,
#    'FlowBytes_s': 172.72744587476382,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 187,
#    'FlowPackets_s': 2.9145761732504187,
#    'FlowBytes_s': 2295.1814932753878,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 188,
#    'FlowPackets_s': 3.606584164683699,
#    'FlowBytes_s': 4190.253921559007,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 189,
#    'FlowPackets_s': 32.5753478248563,
#    'FlowBytes_s': 28193.929685562878,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -24576.0},
#   {'second': 190,
#    'FlowPackets_s': 23.026584923221684,
#    'FlowBytes_s': 7540.2574578476215,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -16384.0},
#   {'second': 191,
#    'FlowPackets_s': 0.1786384143916695,
#    'FlowBytes_s': 49.183009254540885,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 192,
#    'FlowPackets_s': 0.41829695096602293,
#    'FlowBytes_s': 586.213314723866,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 193,
#    'FlowPackets_s': 0.3455163753515679,
#    'FlowBytes_s': 498.5797787967319,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 194,
#    'FlowPackets_s': 28.045953241440948,
#    'FlowBytes_s': 8322.507772852274,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 917504.0},
#   {'second': 195,
#    'FlowPackets_s': 1736.7230377251467,
#    'FlowBytes_s': 857156.3633210023,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -950272.0},
#   {'second': 196,
#    'FlowPackets_s': 0.265980076902146,
#    'FlowBytes_s': 128.44241887318537,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 197,
#    'FlowPackets_s': 0.2924459965036848,
#    'FlowBytes_s': 131.18819422415717,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 198,
#    'FlowPackets_s': 3.7867946992579773,
#    'FlowBytes_s': 2975.449634676164,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 199,
#    'FlowPackets_s': 7.403058518044461,
#    'FlowBytes_s': 3276.186850357193,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 200,
#    'FlowPackets_s': 0.3402630559071115,
#    'FlowBytes_s': 94.84861310255488,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 201,
#    'FlowPackets_s': 23.38215535223614,
#    'FlowBytes_s': 2920.3610509332348,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 202,
#    'FlowPackets_s': 0.5138852580681041,
#    'FlowBytes_s': 54.30700752966281,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 203,
#    'FlowPackets_s': 0.13629652147038052,
#    'FlowBytes_s': 40.13989321805008,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 204,
#    'FlowPackets_s': 0.0915617986400805,
#    'FlowBytes_s': 19.04485411713676,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 205,
#    'FlowPackets_s': 37.265983854008226,
#    'FlowBytes_s': 11145.469959647766,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 206,
#    'FlowPackets_s': 0.19556889002777988,
#    'FlowBytes_s': 75.04551005618147,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 207,
#    'FlowPackets_s': 1.1855647569290158,
#    'FlowBytes_s': 1024.2623488741299,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 208,
#    'FlowPackets_s': 0.15450185994040422,
#    'FlowBytes_s': 31.438240490812497,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 209,
#    'FlowPackets_s': 1.2539584458783817,
#    'FlowBytes_s': 354.4278701868934,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 210,
#    'FlowPackets_s': 1073.5337392581553,
#    'FlowBytes_s': 531345.6586342374,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -557056.0},
#   {'second': 211,
#    'FlowPackets_s': 0.2267474072381064,
#    'FlowBytes_s': 56.40768734116929,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 212,
#    'FlowPackets_s': 0.7888549333339439,
#    'FlowBytes_s': 204.80201975377184,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 262144.0},
#   {'second': 213,
#    'FlowPackets_s': 0.0920560464433262,
#    'FlowBytes_s': 15.301709634185837,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 214,
#    'FlowPackets_s': 324.3892873824645,
#    'FlowBytes_s': 239504.09866755232,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 215,
#    'FlowPackets_s': 0.2563920014603188,
#    'FlowBytes_s': 107.08740394312993,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 216,
#    'FlowPackets_s': 0.6615025747610279,
#    'FlowBytes_s': 377.009002327301,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 217,
#    'FlowPackets_s': 0.923761285307487,
#    'FlowBytes_s': 228.73032349741163,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 218,
#    'FlowPackets_s': 1156.671567919029,
#    'FlowBytes_s': 575413.4290386515,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -557056.0},
#   {'second': 219,
#    'FlowPackets_s': 0.1402129235902349,
#    'FlowBytes_s': 36.71709957731378,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 220,
#    'FlowPackets_s': 1.1222957218780245,
#    'FlowBytes_s': 257.6715533798603,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 221,
#    'FlowPackets_s': 54.0909954411734,
#    'FlowBytes_s': 26701.34201365104,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 222,
#    'FlowPackets_s': 11.196247948498739,
#    'FlowBytes_s': 3569.1923326010537,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 223,
#    'FlowPackets_s': 0.1087674120838488,
#    'FlowBytes_s': 41.15940152272978,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 224,
#    'FlowPackets_s': 0.0726719547506581,
#    'FlowBytes_s': 90.84902743266647,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 225,
#    'FlowPackets_s': 0.1454206787018322,
#    'FlowBytes_s': 40.63724242200688,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 226,
#    'FlowPackets_s': 0.9855957809466829,
#    'FlowBytes_s': 241.3724063004221,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 227,
#    'FlowPackets_s': 0.5433667555877921,
#    'FlowBytes_s': 887.9283944624119,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 228,
#    'FlowPackets_s': 0.2119769834952609,
#    'FlowBytes_s': 63.635118603261205,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 229,
#    'FlowPackets_s': 1318.5715710438924,
#    'FlowBytes_s': 670095.5594161692,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -655360.0},
#   {'second': 230,
#    'FlowPackets_s': 1.1535743364429334,
#    'FlowBytes_s': 290.7780049544488,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 231,
#    'FlowPackets_s': 0.3413834340276922,
#    'FlowBytes_s': 74.89999485826519,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 232,
#    'FlowPackets_s': 1.1862827147089834,
#    'FlowBytes_s': 230.20153398076894,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 233,
#    'FlowPackets_s': 0.9942878683800997,
#    'FlowBytes_s': 855.6530580217511,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 234,
#    'FlowPackets_s': 0.9549577492247037,
#    'FlowBytes_s': 232.4492631126716,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 235,
#    'FlowPackets_s': 992.0789014008218,
#    'FlowBytes_s': 504837.8277897542,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 236,
#    'FlowPackets_s': 0.3818365054422447,
#    'FlowBytes_s': 180.95902237034872,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 237,
#    'FlowPackets_s': 0.7072337190958156,
#    'FlowBytes_s': 381.25138444441785,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 238,
#    'FlowPackets_s': 5.403132479661639,
#    'FlowBytes_s': 1597.3049055822335,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 239,
#    'FlowPackets_s': 2.9240997261664763,
#    'FlowBytes_s': 957.3369218057237,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 240,
#    'FlowPackets_s': 4.6953926435624975,
#    'FlowBytes_s': 5235.577455412938,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 241,
#    'FlowPackets_s': 0.11804619983060011,
#    'FlowBytes_s': 29.33739279046525,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 242,
#    'FlowPackets_s': 0.7285061948634647,
#    'FlowBytes_s': 172.58854762984157,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 243,
#    'FlowPackets_s': 8.155138910926311,
#    'FlowBytes_s': 3435.572623716883,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 244,
#    'FlowPackets_s': 9.759112731221158,
#    'FlowBytes_s': 15357.590401365029,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -16384.0},
#   {'second': 245,
#    'FlowPackets_s': 0.1723513436068024,
#    'FlowBytes_s': 111.40034397613735,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 246,
#    'FlowPackets_s': 0.14541998817255858,
#    'FlowBytes_s': 40.63705233313402,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 247,
#    'FlowPackets_s': 0.7891978851703478,
#    'FlowBytes_s': 212.62489037358398,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 248,
#    'FlowPackets_s': 926.1657789918548,
#    'FlowBytes_s': 462795.73452381126,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -458752.0},
#   {'second': 249,
#    'FlowPackets_s': 0.834783903811243,
#    'FlowBytes_s': 349.2387384145596,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 250,
#    'FlowPackets_s': 65.22501295149536,
#    'FlowBytes_s': 28272.63349349265,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 251,
#    'FlowPackets_s': 0.3818753420285191,
#    'FlowBytes_s': 172.9772629049768,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 252,
#    'FlowPackets_s': 0.32332557707212173,
#    'FlowBytes_s': 194.0585314008948,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 253,
#    'FlowPackets_s': 0.964360767882738,
#    'FlowBytes_s': 1019.280767230233,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 254,
#    'FlowPackets_s': 0.254199185143133,
#    'FlowBytes_s': 61.173438110089535,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 255,
#    'FlowPackets_s': 0.0727395677462289,
#    'FlowBytes_s': 90.87899745294476,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 256,
#    'FlowPackets_s': 23.665731809511072,
#    'FlowBytes_s': 14150.890377120948,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -16384.0},
#   {'second': 257,
#    'FlowPackets_s': 1.1849133135493357,
#    'FlowBytes_s': 290.7003878033262,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 258,
#    'FlowPackets_s': 0.2149427441402176,
#    'FlowBytes_s': 35.60782646431372,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 259,
#    'FlowPackets_s': 0.8881259805340119,
#    'FlowBytes_s': 227.921446137207,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 260,
#    'FlowPackets_s': 993.1166646419649,
#    'FlowBytes_s': 485995.47944862285,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -491520.0},
#   {'second': 261,
#    'FlowPackets_s': 0.0058058119764739,
#    'FlowBytes_s': 0.613899854580183,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 262,
#    'FlowPackets_s': 0.9206869911979312,
#    'FlowBytes_s': 229.2838729447747,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 263,
#    'FlowPackets_s': 0.256584169558175,
#    'FlowBytes_s': 113.13818888801211,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 264,
#    'FlowPackets_s': 0.1862114660719084,
#    'FlowBytes_s': 85.08768637921087,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 265,
#    'FlowPackets_s': 0.1533543493835208,
#    'FlowBytes_s': 86.48378177075928,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 266,
#    'FlowPackets_s': 0.2492876508648138,
#    'FlowBytes_s': 92.92966165278037,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 267,
#    'FlowPackets_s': 1.219063104890957,
#    'FlowBytes_s': 302.84638271323314,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 268,
#    'FlowPackets_s': 1257.3573875789054,
#    'FlowBytes_s': 642756.7511820357,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -622592.0},
#   {'second': 269,
#    'FlowPackets_s': 0.1179727952167539,
#    'FlowBytes_s': 29.492578939686453,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 270,
#    'FlowPackets_s': 0.6973150988763221,
#    'FlowBytes_s': 334.541529680974,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 271,
#    'FlowPackets_s': 396.81186100043,
#    'FlowBytes_s': 161602.09263244076,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -153088.0},
#   {'second': 272,
#    'FlowPackets_s': 1.1594307746995,
#    'FlowBytes_s': 270.9472071388041,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 273,
#    'FlowPackets_s': 33.948531938612774,
#    'FlowBytes_s': 13561.736252001843,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -8192.0},
#   {'second': 274,
#    'FlowPackets_s': 0.4877122343583947,
#    'FlowBytes_s': 67.18236028286887,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 275,
#    'FlowPackets_s': 0.9544524999351233,
#    'FlowBytes_s': 852.5078700848455,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 276,
#    'FlowPackets_s': 0.8229212540715813,
#    'FlowBytes_s': 206.52329187986345,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 277,
#    'FlowPackets_s': 0.4346564254142003,
#    'FlowBytes_s': 152.24890681012783,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 278,
#    'FlowPackets_s': 809.7593976018769,
#    'FlowBytes_s': 402949.665246014,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -393216.0},
#   {'second': 279,
#    'FlowPackets_s': 0.16649520229909248,
#    'FlowBytes_s': 36.807924968650795,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 280,
#    'FlowPackets_s': 0.8219639120178118,
#    'FlowBytes_s': 155.18799280316978,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 281,
#    'FlowPackets_s': 141.2672278728442,
#    'FlowBytes_s': 55270.93997378389,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 282,
#    'FlowPackets_s': 1.4952385534401345,
#    'FlowBytes_s': 948.7801275667522,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 283,
#    'FlowPackets_s': 0.5746831613520168,
#    'FlowBytes_s': 349.00622970500217,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 284,
#    'FlowPackets_s': 1.4236005003138295,
#    'FlowBytes_s': 359.56941167549326,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 285,
#    'FlowPackets_s': 0.6948265368116383,
#    'FlowBytes_s': 203.39209737494446,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 286,
#    'FlowPackets_s': 29.141999898559128,
#    'FlowBytes_s': 21709.870946959738,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 287,
#    'FlowPackets_s': 0.3086521740236994,
#    'FlowBytes_s': 198.15870165947393,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 288,
#    'FlowPackets_s': 644.2780885603638,
#    'FlowBytes_s': 314865.4921636432,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -327680.0},
#   {'second': 289,
#    'FlowPackets_s': 0.9537822728038958,
#    'FlowBytes_s': 231.84140767990795,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 290,
#    'FlowPackets_s': 1.5525778022133752,
#    'FlowBytes_s': 285.8665336635748,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 291,
#    'FlowPackets_s': 1.9260241546516832,
#    'FlowBytes_s': 2796.0306655762333,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 292,
#    'FlowPackets_s': 0.2868796402145819,
#    'FlowBytes_s': 66.91216524284368,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 293,
#    'FlowPackets_s': 0.23950042672206717,
#    'FlowBytes_s': 48.647099972776786,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 294,
#    'FlowPackets_s': 1.5892209639622343,
#    'FlowBytes_s': 1325.881085455625,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 295,
#    'FlowPackets_s': 0.5716882582968171,
#    'FlowBytes_s': 63.31050193798204,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 296,
#    'FlowPackets_s': 0.1453555043061142,
#    'FlowBytes_s': 110.0065747207433,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 297,
#    'FlowPackets_s': 0.1041756841767403,
#    'FlowBytes_s': 28.50868354365872,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 298,
#    'FlowPackets_s': 7.354540704263556,
#    'FlowBytes_s': 12014.411407889851,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 299,
#    'FlowPackets_s': 12.190690694709271,
#    'FlowBytes_s': 15884.469198907766,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 300,
# ...
#   {'second': 906,
#    'FlowPackets_s': 7.205900228330826,
#    'FlowBytes_s': 2958.0866337352877,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 907,
#    'FlowPackets_s': 16.131552380587593,
#    'FlowBytes_s': 8814.398598798263,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 1048576.0},
#   {'second': 908,
#    'FlowPackets_s': 1429.705160589378,
#    'FlowBytes_s': 714820.9847102383,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -720896.0},
#   {'second': 909,
#    'FlowPackets_s': 1.064996690726354,
#    'FlowBytes_s': 1012.9988251943925,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 910,
#    'FlowPackets_s': 0.7894269365337402,
#    'FlowBytes_s': 152.7434370698316,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 911,
#    'FlowPackets_s': 0.1784952886924927,
#    'FlowBytes_s': 48.9132430381504,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 912,
#    'FlowPackets_s': 0.9536750225865849,
#    'FlowBytes_s': 233.71699625082988,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 1048576.0},
#   {'second': 913,
#    'FlowPackets_s': 2002.9800129120015,
#    'FlowBytes_s': 989353.9833968934,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -983040.0},
#   {'second': 914,
#    'FlowPackets_s': 0.9287215837539231,
#    'FlowBytes_s': 239.1134351646005,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 262144.0},
#   {'second': 915,
#    'FlowPackets_s': 744.520847053432,
#    'FlowBytes_s': 280073.4442704548,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 65536.0},
#   {'second': 916,
#    'FlowPackets_s': 563.6163299607091,
#    'FlowBytes_s': 328569.6023019019,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 917,
#    'FlowPackets_s': 16.286126573752817,
#    'FlowBytes_s': 60310.79356219935,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 918,
#    'FlowPackets_s': 0.427384592471,
#    'FlowBytes_s': 771.2538993012283,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 919,
#    'FlowPackets_s': 2.68898150740294,
#    'FlowBytes_s': 614.4388612191293,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 920,
#    'FlowPackets_s': 4.4188204786792875,
#    'FlowBytes_s': 5560.3104729484885,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 921,
#    'FlowPackets_s': 0.9794729667737803,
#    'FlowBytes_s': 656.6946882077734,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 922,
#    'FlowPackets_s': 943.1918550685251,
#    'FlowBytes_s': 311175.0012450175,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 917504.0},
#   {'second': 923,
#    'FlowPackets_s': 398.9864005298391,
#    'FlowBytes_s': 1218189.2089859971,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 924,
#    'FlowPackets_s': 0.8550996502774,
#    'FlowBytes_s': 180.53264089710035,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 925,
#    'FlowPackets_s': 0.2589840115955167,
#    'FlowBytes_s': 75.75828538608775,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 926,
#    'FlowPackets_s': 2156.30824573812,
#    'FlowBytes_s': 1073719.3850212623,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -1048576.0},
#   {'second': 927,
#    'FlowPackets_s': 0.5772187187080784,
#    'FlowBytes_s': 237.7733451007721,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 928,
#    'FlowPackets_s': 0.18563417861854842,
#    'FlowBytes_s': 33.92478391959555,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 929,
#    'FlowPackets_s': 23.796715654182837,
#    'FlowBytes_s': 9164.856865598835,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 16384.0},
#   {'second': 930,
#    'FlowPackets_s': 1.3643341708482088,
#    'FlowBytes_s': 1030.7915385227411,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 931,
#    'FlowPackets_s': 0.9949764461862983,
#    'FlowBytes_s': 233.59146902069295,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 932,
#    'FlowPackets_s': 0.3865218777681254,
#    'FlowBytes_s': 203.64462017785263,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 933,
#    'FlowPackets_s': 0.6231373896321262,
#    'FlowBytes_s': 265.184750206711,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 934,
#    'FlowPackets_s': 0.0698574529909988,
#    'FlowBytes_s': 75.18990523597847,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 935,
#    'FlowPackets_s': 8.483897437684215,
#    'FlowBytes_s': 2790.855934227263,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 936,
#    'FlowPackets_s': 0.6897854382536777,
#    'FlowBytes_s': 225.1647202763913,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 937,
#    'FlowPackets_s': 0.0850133182669415,
#    'FlowBytes_s': 76.51971492372624,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 938,
#    'FlowPackets_s': 0.14896151168364008,
#    'FlowBytes_s': 37.02083192526022,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 939,
#    'FlowPackets_s': 0.1359756619693373,
#    'FlowBytes_s': 40.83802381145764,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 940,
#    'FlowPackets_s': 0.0908515496603339,
#    'FlowBytes_s': 92.52321817408408,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 524288.0},
#   {'second': 941,
#    'FlowPackets_s': 1463.3629679160365,
#    'FlowBytes_s': 751656.721039443,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -688128.0},
#   {'second': 942,
#    'FlowPackets_s': 145.3313709161687,
#    'FlowBytes_s': 39301.40108969219,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 278528.0},
#   {'second': 943,
#    'FlowPackets_s': 849.1926875833346,
#    'FlowBytes_s': 318630.6733779736,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 944,
#    'FlowPackets_s': 3.294935371435431,
#    'FlowBytes_s': 4344.772214525704,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 945,
#    'FlowPackets_s': 1.0910782831128696,
#    'FlowBytes_s': 241.65446739830594,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 946,
#    'FlowPackets_s': 15.675806932136226,
#    'FlowBytes_s': 4412.739651396348,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 16384.0},
#   {'second': 947,
#    'FlowPackets_s': 22.63703005413729,
#    'FlowBytes_s': 19264.11257607084,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -12288.0},
#   {'second': 948,
#    'FlowPackets_s': 13.618142613270344,
#    'FlowBytes_s': 7264.241330453312,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 949,
#    'FlowPackets_s': 19.097302795752555,
#    'FlowBytes_s': 5461.331517017287,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 950,
#    'FlowPackets_s': 1.229535021310025,
#    'FlowBytes_s': 269.1923124941927,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 951,
#    'FlowPackets_s': 0.6592857120732821,
#    'FlowBytes_s': 296.6273541895744,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 952,
#    'FlowPackets_s': 2148.790649873283,
#    'FlowBytes_s': 1060048.1845894407,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -1048576.0},
#   {'second': 953,
#    'FlowPackets_s': 0.891194876178834,
#    'FlowBytes_s': 228.70518800345218,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 954,
#    'FlowPackets_s': 0.25298336690084167,
#    'FlowBytes_s': 127.94756942297414,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 955,
#    'FlowPackets_s': 1.1515682376936325,
#    'FlowBytes_s': 395.90608564056646,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 956,
#    'FlowPackets_s': 0.6138959252782077,
#    'FlowBytes_s': 531.1419268557308,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 957,
#    'FlowPackets_s': 2.5869989261647355,
#    'FlowBytes_s': 2923.8489748751813,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 958,
#    'FlowPackets_s': 2.5935571054446047,
#    'FlowBytes_s': 4303.097310749968,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 959,
#    'FlowPackets_s': 0.7489761462410446,
#    'FlowBytes_s': 409.1962546108974,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 960,
#    'FlowPackets_s': 0.30031225046467447,
#    'FlowBytes_s': 139.59639267236616,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 961,
#    'FlowPackets_s': 0.16979260884655079,
#    'FlowBytes_s': 35.729195572550495,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 962,
#    'FlowPackets_s': 1538.1916015114996,
#    'FlowBytes_s': 760019.6022510149,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -753664.0},
#   {'second': 963,
#    'FlowPackets_s': 1.4397961744283785,
#    'FlowBytes_s': 1681.7881654273294,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 964,
#    'FlowPackets_s': 2.58111600719674,
#    'FlowBytes_s': 1505.083021214859,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 965,
#    'FlowPackets_s': 0.1110831185619591,
#    'FlowBytes_s': 28.91499044544905,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 966,
#    'FlowPackets_s': 1.0198050221582098,
#    'FlowBytes_s': 236.49876063427018,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 967,
#    'FlowPackets_s': 10.933107550063765,
#    'FlowBytes_s': 3785.922139594928,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 968,
#    'FlowPackets_s': 22.809432476434413,
#    'FlowBytes_s': 16331.447518728368,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 969,
#    'FlowPackets_s': 49.47508113354961,
#    'FlowBytes_s': 8079.3790159382315,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 970,
#    'FlowPackets_s': 0.34343085609476576,
#    'FlowBytes_s': 165.69575835993777,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 971,
#    'FlowPackets_s': 1250.6235113909158,
#    'FlowBytes_s': 612263.9834550148,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -622592.0},
#   {'second': 972,
#    'FlowPackets_s': 0.8555163428414974,
#    'FlowBytes_s': 157.04608621478368,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 973,
#    'FlowPackets_s': 0.1205589597782756,
#    'FlowBytes_s': 58.13020464067686,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 974,
#    'FlowPackets_s': 0.1247159382111035,
#    'FlowBytes_s': 49.05909289430775,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 975,
#    'FlowPackets_s': 0.36444591934877957,
#    'FlowBytes_s': 154.06061595006048,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 976,
#    'FlowPackets_s': 567.0455859691506,
#    'FlowBytes_s': 216256.53028105892,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -262144.0},
#   {'second': 977,
#    'FlowPackets_s': 1.6132272370042913,
#    'FlowBytes_s': 378.5996061821986,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 978,
#    'FlowPackets_s': 6.321390406694514,
#    'FlowBytes_s': 2132.11368728547,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 1048576.0},
#   {'second': 979,
#    'FlowPackets_s': 2410.4953688428454,
#    'FlowBytes_s': 1208977.7952740053,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -1179648.0},
#   {'second': 980,
#    'FlowPackets_s': 0.7281462835262912,
#    'FlowBytes_s': 369.4222586726653,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 981,
#    'FlowPackets_s': 1.1461590678607816,
#    'FlowBytes_s': 284.5956871427021,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 982,
#    'FlowPackets_s': 0.2962587128509429,
#    'FlowBytes_s': 73.20720088497372,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 983,
#    'FlowPackets_s': 0.2960998940585735,
#    'FlowBytes_s': 177.6984641373727,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 984,
#    'FlowPackets_s': 0.203745995391276,
#    'FlowBytes_s': 64.32522130927413,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 985,
#    'FlowPackets_s': 0.35802303455900986,
#    'FlowBytes_s': 164.7100020373087,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 986,
#    'FlowPackets_s': 0.4539403049071259,
#    'FlowBytes_s': 63.62914469027445,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 987,
#    'FlowPackets_s': 0.675719701144759,
#    'FlowBytes_s': 956.4646209121814,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 988,
#    'FlowPackets_s': 0.2499053078888432,
#    'FlowBytes_s': 65.44146184642071,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 1048576.0},
#   {'second': 989,
#    'FlowPackets_s': 1469.4934606461086,
#    'FlowBytes_s': 746053.3187845512,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': -720896.0},
#   {'second': 990,
#    'FlowPackets_s': 0.1997273569962032,
#    'FlowBytes_s': 55.30868719434585,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 991,
#    'FlowPackets_s': 0.9928574842584913,
#    'FlowBytes_s': 233.49231510203765,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 992,
#    'FlowPackets_s': 12.104251881588679,
#    'FlowBytes_s': 4721.08336826807,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 993,
#    'FlowPackets_s': 0.4717525871586012,
#    'FlowBytes_s': 112.51299203732638,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 994,
#    'FlowPackets_s': 28.47127415561997,
#    'FlowBytes_s': 8143.426955137586,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 995,
#    'FlowPackets_s': 1.8305700110868317,
#    'FlowBytes_s': 2007.447949680056,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 996,
#    'FlowPackets_s': 6.357911897053233,
#    'FlowBytes_s': 1547.4365112812773,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 997,
#    'FlowPackets_s': 0.1268927896548735,
#    'FlowBytes_s': 40.20688677921566,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 998,
#    'FlowPackets_s': 0.118197698677552,
#    'FlowBytes_s': 93.3852740859336,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 999,
#    'FlowPackets_s': 1.1257380386926765,
#    'FlowBytes_s': 252.33094167844422,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   {'second': 1000,
#    'FlowPackets_s': 0.4534874167930965,
#    'FlowBytes_s': 211.9037807953589,
#    'Label': 'BENIGN',
#    'Warning': 'BENIGN',
#    'score': 0.0},
#   ...],
#  'max_seconds': 1417,
#  'confusion_matrices': {'LOW': [[1019, 1], [0, 0]],
#   'MED': [[1019, 1], [0, 0]],
#   'HIGH': [[1018, 2], [0, 0]]},
#  'confusion_metrics': {'LOW': {'accuracy': 0.9990196078431373,
#    'precision_attack': 0.0,
#    'recall_attack': 0.0,
#    'f1_attack': 0.0,
#    'balanced_accuracy': 0.9990196078431373},
#   'MED': {'accuracy': 0.9990196078431373,
#    'precision_attack': 0.0,
#    'recall_attack': 0.0,
#    'f1_attack': 0.0,
#    'balanced_accuracy': 0.9990196078431373},
#   'HIGH': {'accuracy': 0.9980392156862745,
#    'precision_attack': 0.0,
#    'recall_attack': 0.0,
#    'f1_attack': 0.0,
#    'balanced_accuracy': 0.9980392156862745}},
#  'first_low': 107.0,
#  'first_med': 708.0,
#  'first_high': 421.0,
#  'peak_sec': 1020,
#  'peak_val': 2104478.2951965067}

# %%
# results_1

# %%
# test1_path['Label'].value_counts()

# %%
# results_folder = Path(RESULTS_FOLDER)
# with open(results_folder / "model.pkl", "rb") as f:
#     model = pickle.load(f)
# with open(results_folder / "thresholds.pkl", "rb") as f:
#     th = pickle.load(f)
# LOW_THR = th["LOW_THR"]
# MED_THR = th["MED_THR"]
# HIGH_THR = th["HIGH_THR"]

# %%
# print(LOW_THR, MED_THR, HIGH_THR)
